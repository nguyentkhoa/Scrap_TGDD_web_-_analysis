# %% [markdown]
# # 📋 Data Cleaning: Best Selling Phones

# %% [markdown]
# ## 🛠️ 1. Import libraries and load raw data

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
import re
import datetime
from datetime import datetime

# Load the raw dataset
file = 'product_2025_05_07.csv'
df = pd.read_csv(file)

# %% [markdown]
# ## 🛠️ 2. Clean missing values

# %%
# Replace missing values with 'NaN'
list_na=dict(df.isna().sum())
for col,count in list_na.items():
    if count > 0:
        df.loc[df[col].isna(),col] = 'NaN'

# %% [markdown]
# ## 🛠️3. Clean text fields (Utility, Screen, Rating)

# %%
# Clean text fields by removing newline characters and extra spaces

def clean_utility(row):
    return ' '.join(row.replace('\n','').strip(' ').split())
df['phone_utility']=df['phone_utility'].apply(clean_utility)

def clean_screen(row):
    _=row.replace('\n','').strip().split()
    return ' '.join(_)
df['phone_screen']=df['phone_screen'].apply(clean_screen)

def clean_rating(row):
    _=row.replace('\n','').strip().split()
    return ' '.join(_)
df['phone_rating']=df['phone_rating'].apply(clean_rating)

# %%
df
# Out:
#      phone_id                                  phone_name  phone_price  \
# 0      323543               Điện thoại OPPO A60 8GB/128GB    5490000.0
# 1      329149          Điện thoại iPhone 16 Pro Max 256GB   30990000.0
# 2      333147   Điện thoại Xiaomi Redmi Note 14 8GB/128GB    5490000.0
# 3      332936       Điện thoại OPPO Reno13 F 5G 8GB/256GB    9990000.0
# 4      335755       Điện thoại Xiaomi Redmi 13x 6GB/128GB    4290000.0
# ..        ...                                         ...          ...
# 118    319904  Điện thoại Samsung Galaxy A25 5G 8GB/128GB    6490000.0
# 119    320836               Điện thoại OPPO A38 6GB/128GB    3990000.0
# 120    320964  Điện thoại Samsung Galaxy M15 5G 6GB/128GB    4990000.0
# 121    330619         Điện thoại realme 13+ 5G 12GB/256GB    9990000.0
# 122    335925           Điện thoại Samsung Galaxy S Mới 2   29990000.0
#
#         phone_brand    category  \
# 0              OPPO  Điện thoại
# 1    iPhone (Apple)  Điện thoại
# 2            Xiaomi  Điện thoại
# 3              OPPO  Điện thoại
# 4            Xiaomi  Điện thoại
# ..              ...         ...
# 118         Samsung  Điện thoại
# 119            OPPO  Điện thoại
# 120         Samsung  Điện thoại
# 121          realme  Điện thoại
# 122         Samsung  Điện thoại
#
#                                              phone_img           phone_screen  \
# 0    https://cdn.tgdd.vn/Products/Images/42/323543/...              HD+ 6.67"
# 1    https://cdn.tgdd.vn/Products/Images/42/329149/...  Super Retina XDR 6.9"
# 2    https://cdn.tgdd.vn/Products/Images/42/333147/...         Full HD+ 6.67"
# 3    https://cdn.tgdd.vn/Products/Images/42/332936/...         Full HD+ 6.67"
# 4    https://cdn.tgdd.vn/Products/Images/42/335755/...         Full HD+ 6.79"
# ..                                                 ...                    ...
# 118  https://cdn.tgdd.vn/Products/Images/42/319904/...          Full HD+ 6.5"
# 119  https://cdn.tgdd.vn/Products/Images/42/320836/...              HD+ 6.56"
# 120  https://cdn.tgdd.vn/Products/Images/42/320964/...          Full HD+ 6.5"
# 121  https://cdn.tgdd.vn/Products/Images/42/330619/...         Full HD+ 6.67"
# 122  https://cdnv2.tgdd.vn/mwg-static/tgdd/Products...                    NaN
#
#                                          phone_utility  \
# 0    Chip Snapdragon 680 RAM: 8 GB Dung lượng: 128 ...
# 1    Chip Apple A18 Pro 6 nhân RAM: 8 GB Dung lượng...
# 2    Chip MediaTek Helio G99-Ultra 8 nhân RAM: 8 GB...
# 3    Chip Snapdragon 6 Gen 1 5G 8 nhân RAM: 8 GB Du...
# 4    Chip MediaTek Helio G91 Ultra 8 nhân RAM: 6 GB...
# ..                                                 ...
# 118  Chip Exynos 1280 RAM: 8 GB Dung lượng: 128 GB ...
# 119  Chip MediaTek Helio G85 RAM: 6 GB Dung lượng: ...
# 120  Chip MediaTek Dimensity 6100+ RAM: 6 GB Dung l...
# 121  Chip MediaTek Dimensity 7300 Energy 5G 8 nhân ...
# 122  Camera sau: Đang cập nhật Camera trước: Đang...
#
#                     phone_rating
# 0    4.9 • Đã bán 230,2k So sánh
# 1    4.9 • Đã bán 159,8k So sánh
# 2     4.9 • Đã bán 78,9k So sánh
# 3     4.9 • Đã bán 66,3k So sánh
# 4       5 • Đã bán 15,2k So sánh
# ..                           ...
# 118   4.9 • Đã bán 79,4k So sánh
# 119  4.9 • Đã bán 127,7k So sánh
# 120   4.9 • Đã bán 95,5k So sánh
# 121    4.9 • Đã bán 2,4k So sánh
# 122                      So sánh
#
# [123 rows x 9 columns]

# %% [markdown]
# ## 🛠️ 4. Extract numeric values from 'phone_rating'

# %%
# Extract number of votes
def enrich_vote_rating_raw(row):
    _ = row.split()[0]
    return _.replace('•','')
df['vote_rating'] = df['phone_rating'].apply(enrich_vote_rating_raw)

# # Extract sold quantity
def enrich_sold_quantity_raw(row):
    pattern=r'\d{1,3}(?:,\d{1,3})?k?'
    try:
         return re.findall(pattern,row)[-1]
    except:
        return 0
df['phone_rating'].apply(enrich_sold_quantity_raw)

df['sold_quantity'] = df['phone_rating'].apply(enrich_sold_quantity_raw)

# # Replace non-numeric vote ratings with 0
df.loc[df['vote_rating'].str.isalpha(), 'vote_rating'] = 0

# %% [markdown]
# ## 🛠️ 5. Convert 'sold_quantity' to numeric format

# %%
# Handle 'k' (thousands) unit and convert to integer
def enrich_sold_quantity(row):
    if str(row).find('k') > 0:
        _ = int(row.replace(',','').replace('k','')) * 1000
        return _
    else:
        return row
df['sold_quantity']=df['sold_quantity'].apply(enrich_sold_quantity)

# %% [markdown]
# ## 🛠️ 6. Clean the 'phone_screen' field

# %%
# Remove double quotes and clean screen information
def clean_phone_screen(row):
    return row.replace('"','').strip()
df['phone_screen'] = df['phone_screen'].apply(clean_phone_screen)

# %% [markdown]
# ## 🛠️ 7. Transform data types

# %%
# Convert price, sold quantity, and rating to numeric types
df['phone_price'] = df['phone_price'].astype('int64')
df['sold_quantity'] = df['sold_quantity'].astype('int64')
df['vote_rating'] = df['vote_rating'].astype('float64')

# %% [markdown]
# ## 🛠️ 8. Remove outliers

# %%
# Remove products with sold quantity equal to zero
df_2 = df.copy()
df_2 = df_2[df_2['sold_quantity'] > 0]

# %% [markdown]
# ## 🛠️ 9. Enrich data: calculate gross revenue

# %%
# Calculate gross revenue (sold quantity × price)
df_2['gross_revenue'] = df_2['sold_quantity'] * df_2['phone_price']

# %% [markdown]
# ## 🛠️ 10. Create price segment

# %%
# Categorize phones into different price segments
def price_segment(row):
    if row < 10000000:
        return '0 to 10M VND'
    elif row < 20000000:
        return '10M to 20M VND'
    else:
        return 'Upper 20M VND'
df_2['price_segment'] = df_2['phone_price'].apply(price_segment)

# %% [markdown]
# ## 🛠️ 11. Extract screen size and screen type

# %%
# Extract screen size (in inches)
def return_size_screen_phone(row):
    list_row = row.split()
    length_list = len(list_row)
    if length_list < 2:
        return ' '.join(list_row)
    elif length_list < 5:
        return list_row[-1]
    else:
        return ' '.join(list_row[list_row.index('Chính'):])
df_2['size_screen_inch'] = df_2['phone_screen'].apply(return_size_screen_phone)

# Extract screen type
def return_screen_phone(row):
    list_row = row.split()
    length_list = len(list_row)
    if length_list < 2:
        return ' '.join(list_row)
    elif length_list < 5:
        return ' '.join(list_row[:-1])
    else:
        return ' '.join(list_row[:list_row.index('Chính')])

def detail_none_screen(row):
    _ = row.replace('.', '')
    if _.isdigit():
        return 'NaN'
    else:
        return row
df_2['info_screen'] = df_2['phone_screen'].apply(return_screen_phone).apply(detail_none_screen)

# %% [markdown]
# ## 🛠️ 12. Create rating segment

# %%
# Categorize phones based on customer ratings
def rating_segment(row):
    if 0 < row < 3:
        return 'Poor'
    elif 3 < row < 4.5:
        return 'Average'
    else:
        return 'Excellent'
df_2['rating_segment'] = df_2['vote_rating'].apply(rating_segment)

# %% [markdown]
# ## 🛠️ 13. Extract RAM, ROM, and battery capacity

# %%
# Extract RAM and ROM information
def return_ram(row):
    list_row = row.split()
    if 'RAM:' in list_row and 'lượng:' in list_row:
        ram_idx = list_row.index('RAM:')
        return list_row[ram_idx+1]
    else:
        return 'NaN'

def return_rom(row):
    list_row = row.split()
    if 'RAM:' in list_row and 'lượng:' in list_row:
        rom_idx = list_row.index('lượng:')
        return list_row[rom_idx+1]
    else:
        return 'NaN'

df_2['RAM(GB)'] = df_2['phone_utility'].apply(return_ram)
df_2['ROM(GB)'] = df_2['phone_utility'].apply(return_rom)

# Extract battery capacity
def return_battery(row):
    list_row = row.split()
    if 'Pin' in list_row:
        pin_idx = list_row.index('Pin')
        return ' '.join(list_row[pin_idx+1:pin_idx+3]).replace(',', '')
    else:
        return 'NaN'
df_2['battery'] = df_2['phone_utility'].apply(return_battery)

# %% [markdown]
# ## 🛠️ 14. Create new columns: price in million VND and revenue in billion VND

# %%
# Price in Million VND
df_2['phone_price_Milion_VND'] = df_2['phone_price'] / 1_000_000

# Gross revenue in Billion VND
df_2['gross_revenue_Bilion_VND'] = df_2['gross_revenue'] / 1_000_000_000

# %% [markdown]
# ## 🛠️ 15. Finalize the cleaned dataset

# %%
# Drop unnecessary columns
df_3 = df_2.drop(['phone_rating','phone_screen','category','phone_id'], axis=1)

# Reorder columns
df_3 = df_3[['phone_name','phone_brand','phone_price','phone_price_Milion_VND','phone_img','phone_utility','RAM(GB)','ROM(GB)','battery','info_screen','size_screen_inch','vote_rating','price_segment','rating_segment','sold_quantity','gross_revenue','gross_revenue_Bilion_VND']]

# Save cleaned dataset
file = f'Best_sell_phone_cleaned.csv'
df_3.to_csv(file, index=False)

# %%
df_3
# Out:
#                                      phone_name     phone_brand  phone_price  \
# 0                 Điện thoại OPPO A60 8GB/128GB            OPPO      5490000
# 1            Điện thoại iPhone 16 Pro Max 256GB  iPhone (Apple)     30990000
# 2     Điện thoại Xiaomi Redmi Note 14 8GB/128GB          Xiaomi      5490000
# 3         Điện thoại OPPO Reno13 F 5G 8GB/256GB            OPPO      9990000
# 4         Điện thoại Xiaomi Redmi 13x 6GB/128GB          Xiaomi      4290000
# ..                                          ...             ...          ...
# 117    Điện thoại Samsung Galaxy A05s 6GB/128GB         Samsung      3990000
# 118  Điện thoại Samsung Galaxy A25 5G 8GB/128GB         Samsung      6490000
# 119               Điện thoại OPPO A38 6GB/128GB            OPPO      3990000
# 120  Điện thoại Samsung Galaxy M15 5G 6GB/128GB         Samsung      4990000
# 121         Điện thoại realme 13+ 5G 12GB/256GB          realme      9990000
#
#      phone_price_Milion_VND  \
# 0                      5.49
# 1                     30.99
# 2                      5.49
# 3                      9.99
# 4                      4.29
# ..                      ...
# 117                    3.99
# 118                    6.49
# 119                    3.99
# 120                    4.99
# 121                    9.99
#
#                                              phone_img  \
# 0    https://cdn.tgdd.vn/Products/Images/42/323543/...
# 1    https://cdn.tgdd.vn/Products/Images/42/329149/...
# 2    https://cdn.tgdd.vn/Products/Images/42/333147/...
# 3    https://cdn.tgdd.vn/Products/Images/42/332936/...
# 4    https://cdn.tgdd.vn/Products/Images/42/335755/...
# ..                                                 ...
# 117  https://cdn.tgdd.vn/Products/Images/42/317530/...
# 118  https://cdn.tgdd.vn/Products/Images/42/319904/...
# 119  https://cdn.tgdd.vn/Products/Images/42/320836/...
# 120  https://cdn.tgdd.vn/Products/Images/42/320964/...
# 121  https://cdn.tgdd.vn/Products/Images/42/330619/...
#
#                                          phone_utility RAM(GB) ROM(GB)  \
# 0    Chip Snapdragon 680 RAM: 8 GB Dung lượng: 128 ...       8     128
# 1    Chip Apple A18 Pro 6 nhân RAM: 8 GB Dung lượng...       8     256
# 2    Chip MediaTek Helio G99-Ultra 8 nhân RAM: 8 GB...       8     128
# 3    Chip Snapdragon 6 Gen 1 5G 8 nhân RAM: 8 GB Du...       8     256
# 4    Chip MediaTek Helio G91 Ultra 8 nhân RAM: 6 GB...       6     128
# ..                                                 ...     ...     ...
# 117  Chip Snapdragon 680 RAM: 6 GB Dung lượng: 128 ...       6     128
# 118  Chip Exynos 1280 RAM: 8 GB Dung lượng: 128 GB ...       8     128
# 119  Chip MediaTek Helio G85 RAM: 6 GB Dung lượng: ...       6     128
# 120  Chip MediaTek Dimensity 6100+ RAM: 6 GB Dung l...       6     128
# 121  Chip MediaTek Dimensity 7300 Energy 5G 8 nhân ...      12     256
#
#       battery       info_screen size_screen_inch  vote_rating  price_segment  \
# 0    5000 mAh               HD+             6.67          4.9   0 to 10M VND
# 1      33 giờ  Super Retina XDR              6.9          4.9  Upper 20M VND
# 2    5500 mAh          Full HD+             6.67          4.9   0 to 10M VND
# 3    5800 mAh          Full HD+             6.67          4.9   0 to 10M VND
# 4    5030 mAh          Full HD+             6.79          5.0   0 to 10M VND
# ..        ...               ...              ...          ...            ...
# 117  5000 mAh          Full HD+              6.7          4.9   0 to 10M VND
# 118  5000 mAh          Full HD+              6.5          4.9   0 to 10M VND
# 119  5000 mAh               HD+             6.56          4.9   0 to 10M VND
# 120  6000 mAh          Full HD+              6.5          4.9   0 to 10M VND
# 121  5000 mAh          Full HD+             6.67          4.9   0 to 10M VND
#
#     rating_segment  sold_quantity   gross_revenue  gross_revenue_Bilion_VND
# 0        Excellent        2302000  12637980000000                  12637.98
# 1        Excellent        1598000  49522020000000                  49522.02
# 2        Excellent         789000   4331610000000                   4331.61
# 3        Excellent         663000   6623370000000                   6623.37
# 4        Excellent         152000    652080000000                    652.08
# ..             ...            ...             ...                       ...
# 117      Excellent        1284000   5123160000000                   5123.16
# 118      Excellent         794000   5153060000000                   5153.06
# 119      Excellent        1277000   5095230000000                   5095.23
# 120      Excellent         955000   4765450000000                   4765.45
# 121      Excellent          24000    239760000000                    239.76
#
# [122 rows x 17 columns]
